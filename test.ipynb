# %%
#Solución:
import pandas as pd
# Cargar datos desde el archivo CSV
data = pd.read_csv('data - Sheet1.csv',sep=',')

# %%
data
# Out:
#         Patient ID  Gender       Patient Type  Age Insurance Class  \
# 0            19556  Female    Regular Patient   52   Private   Low
# 1            90035  Female    Regular Patient   36   Private  High
# 2            12360    Male  Irregular Patient   20   Private   Low
# 3            77959    Male    Regular Patient   44   Private  High
# 4            36875  Female    Regular Patient   49   Private   Low
# ...            ...     ...                ...  ...       ...   ...
# 129875       94171  Female  Irregular Patient   23   Private   Low
# 129876       73097    Male    Regular Patient   49   Private  High
# 129877       68825    Male  Irregular Patient   30   Private  High
# 129878       54173  Female  Irregular Patient   22   Private   Low
# 129879       62567    Male    Regular Patient   27   Private  High
#
#         Clinic Distance  Wifi  Time convenience  Online booking  ...  \
# 0                   160     5                 4               3  ...
# 1                  2863     1                 1               3  ...
# 2                   192     2                 0               2  ...
# 3                  3377     0                 0               0  ...
# 4                  1182     2                 3               4  ...
# ...                 ...   ...               ...             ...  ...
# 129875              192     2                 1               2  ...
# 129876             2347     4                 4               4  ...
# 129877             1995     1                 1               1  ...
# 129878             1000     1                 1               1  ...
# 129879             1723     1                 3               3  ...
#
#         Inflight entertainment  Pre-entry service  Post-entry service  \
# 0                            5                  5                   5
# 1                            4                  4                   4
# 2                            2                  4                   1
# 3                            1                  1                   1
# 4                            2                  2                   2
# ...                        ...                ...                 ...
# 129875                       2                  3                   1
# 129876                       5                  5                   5
# 129877                       4                  3                   2
# 129878                       1                  4                   5
# 129879                       1                  1                   1
#
#         Visitor service  Check-in service  Medic service  Cleanliness  \
# 0                     5                 2              5            5
# 1                     4                 3              4            5
# 2                     3                 2              2            2
# 3                     1                 3              1            4
# 4                     2                 4              2            4
# ...                 ...               ...            ...          ...
# 129875                4                 2              3            2
# 129876                5                 5              5            4
# 129877                4                 5              5            4
# 129878                1                 5              4            1
# 129879                4                 4              3            1
#
#         Waiting time (min)  Delay in care (min)  Satisfaction
# 0                       50                 44.0     satisfied
# 1                        0                  0.0     satisfied
# 2                        0                  0.0  dissatisfied
# 3                        0                  6.0     satisfied
# 4                        0                 20.0     satisfied
# ...                    ...                  ...           ...
# 129875                   3                  0.0  dissatisfied
# 129876                   0                  0.0     satisfied
# 129877                   7                 14.0  dissatisfied
# 129878                   0                  0.0  dissatisfied
# 129879                   0                  0.0  dissatisfied
#
# [129880 rows x 24 columns]

# %%
data['Delay in care (min)'].std()
# Out:
# 38.46565024014789

# %%
s = data[data['Satisfaction'] == 'satisfied']
len(s)
# Out:
# 56428

# %%
d = data[data['Satisfaction'] == 'dissatisfied']
len(d)
# Out:
# 73452

# %%
(73452/129880)*100
# Out:
# 56.55374191561441

# %%
(i/129880)*100
# Out:
# 18.30920850015399

# %%
cero=data[data['Wifi'] == 0]

# %%
cero
# Out:
#         Patient ID  Gender       Patient Type  Age   Insurance   Class  \
# 3            77959    Male    Regular Patient   44     Private    High
# 120          27872    Male    Regular Patient   25     Private  Medium
# 188          51281  Female    Regular Patient   30     Private  Medium
# 199         117345    Male  Irregular Patient   25     Private    High
# 203          70631  Female    Regular Patient   61  Subsidized     Low
# ...            ...     ...                ...  ...         ...     ...
# 129609       99728    Male    Regular Patient   36     Private    High
# 129627      108633  Female    Regular Patient   57  Subsidized     Low
# 129659       17529  Female  Irregular Patient   24     Private  Medium
# 129704       15861  Female    Regular Patient   49     Private    High
# 129834       69123    Male    Regular Patient   51  Subsidized     Low
#
#         Clinic Distance  Wifi  Time convenience  Online booking  ...  \
# 3                  3377     0                 0               0  ...
# 120                 680     0                 5               0  ...
# 188                 326     0                 0               0  ...
# 199                 296     0                 0               0  ...
# 203                1217     0                 4               0  ...
# ...                 ...   ...               ...             ...  ...
# 129609             2799     0                 0               0  ...
# 129627             1547     0                 4               0  ...
# 129659              241     0                 2               0  ...
# 129704             3578     0                 0               0  ...
# 129834             1598     0                 5               0  ...
#
#         Inflight entertainment  Pre-entry service  Post-entry service  \
# 3                            1                  1                   1
# 120                          1                  3                   1
# 188                          2                  4                   1
# 199                          2                  4                   4
# 203                          4                  4                   0
# ...                        ...                ...                 ...
# 129609                       2                  2                   2
# 129627                       1                  1                   0
# 129659                       2                  3                   4
# 129704                       5                  5                   5
# 129834                       3                  3                   2
#
#         Visitor service  Check-in service  Medic service  Cleanliness  \
# 3                     1                 3              1            4
# 120                   4                 5              5            1
# 188                   3                 4              5            2
# 199                   4                 5              5            2
# 203                   4                 4              4            4
# ...                 ...               ...            ...          ...
# 129609                2                 3              2            4
# 129627                1                 4              1            3
# 129659                2                 5              3            2
# 129704                5                 4              5            3
# 129834                3                 3              4            3
#
#         Waiting time (min)  Delay in care (min)  Satisfaction
# 3                        0                  6.0     satisfied
# 120                      0                  0.0     satisfied
# 188                      0                  0.0     satisfied
# 199                      0                  0.0     satisfied
# 203                      0                  0.0     satisfied
# ...                    ...                  ...           ...
# 129609                  17                 10.0     satisfied
# 129627                   3                  3.0     satisfied
# 129659                   1                  0.0     satisfied
# 129704                  65                 95.0     satisfied
# 129834                   1                  1.0     satisfied
#
# [3916 rows x 24 columns]

# %%
male = cero[cero['Satisfaction'] == 'satisfied']
len(male)
# Out:
# 3906

# %%
female = cero[cero['Satisfaction'] == 'dissatisfied']
len(female)
# Out:
# 10
